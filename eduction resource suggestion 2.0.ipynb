# %%
import pandas as pd
import numpy as np

# Define the lists of information
text_books = ['Advanced Statistics Concepts', 'Advanced International Relations Concepts', 'Mastering Marketing', 'Introduction to Engineering', 'Mastering Human Resources Management', 'Introduction to Civil Engineering', 'Advanced Development Studies Concepts', 'Mastering Physics', 'Mastering Conflict Resolution', 'Advanced Environmental Science Concepts', 'Artificial Intelligence for Beginners', 'Anthropology for Beginners', 'Psychology for Beginners', 'Marine Biology for Beginners', 'Advanced English Language Concepts', 'Introduction to Cognitive Science', 'Mastering Chemistry', 'International Relations Essentials', 'Mastering Wilderness Survival', 'Music Theory for Beginners', 'Geography Essentials', 'Advanced Social Media Management Concepts', 'Introduction to Law', 'Introduction to Wilderness Survival', 'Introduction to Geography', 'Introduction to Genetics', 'Mastering Computer Science', 'Conflict Resolution Essentials', 'Biology Essentials', 'Cryptography for Beginners', 'Materials Science for Beginners', 'Geology Essentials', 'Sports Science Essentials', 'Law Essentials', 'Civil Engineering for Beginners', 'Electrical Engineering for Beginners', 'Mastering Economics', 'Mastering Microeconomics', 'Advanced Paleontology Concepts', 'Nanotechnology Essentials', 'Advanced Photography Concepts', 'Wilderness Survival for Beginners', 'Introduction to Development Studies', 'Geology for Beginners', 'Deep Learning Essentials', 'Introduction to Pharmacology', 'Advanced Journalism Concepts', 'Environmental Science Essentials', 'Wilderness Survival Essentials', 'Mechanical Engineering Essentials', 'Aerospace Engineering for Beginners', 'Introduction to Supply Chain Management', 'Paleontology Essentials', 'Advanced Conflict Resolution Concepts', 'Machine Learning Essentials', 'Mastering Mathematics', 'Advanced Game Theory Concepts', 'Mastering Human Rights', 'Advanced Religious Studies Concepts', 'Macroeconomics for Beginners', 'Advanced Interior Design Concepts', 'Zoology for Beginners', 'Art History Essentials', 'Agriculture Essentials', 'Advanced Industrial Psychology Concepts', 'Introduction to Materials Science', 'Theater Arts Essentials', 'Ethics for Beginners', 'Mastering Cybersecurity', 'Physics for Beginners', 'Communication Studies Essentials', 'Mastering Statistics', 'Software Engineering Essentials', 'Advanced Developmental Psychology Concepts', 'Introduction to Journalism', 'Literature Essentials', 'Neurobiology Essentials', 'Advanced Sports Science Concepts', 'Advanced Forensic Science Concepts', 'Graphic Design Essentials', 'Cognitive Science Essentials', 'Public Relations for Beginners', 'Introduction to Medicine', 'Biochemistry for Beginners', 'Mastering Pharmacology', 'Introduction to Public Relations', 'Advanced Human Resources Management Concepts', 'Quantum Computing for Beginners', 'Introduction to Neurobiology', 'Introduction to Artificial Intelligence', 'Introduction to Literature', 'Introduction to Cryptocurrency', 'Sociology Essentials', 'Mastering Anthropology', 'Mastering Cultural Studies', 'Astronomy for Beginners', 'Introduction to Data Science', 'Advanced Behavioral Economics Concepts', 'Advanced Marketing Concepts', 'Religious Studies for Beginners', 'Art History for Beginners', 'Mastering Environmental Science', 'Supply Chain Management for Beginners', 'Mastering Ethics', 'Advanced Music Composition Concepts', 'Introduction to Music Theory', 'Biochemistry Essentials', 'Advanced Physics Concepts', 'Mastering Forensic Science', 'Introduction to Information Technology', 'Introduction to Robotics', 'Mastering Cryptography', 'Advanced Chemistry Concepts', 'Advanced Architecture Concepts', 'Advanced Cultural Studies Concepts', 'Business Administration for Beginners', 'Introduction to Statistics', 'Advanced Anthropology Concepts', 'Mastering Operations Management', 'Advanced Data Science Concepts', 'Biology for Beginners', 'Zoology Essentials', 'Advanced Macroeconomics Concepts', 'Mastering Astronomy', 'Advanced Philosophy Concepts', 'Astronomy Essentials', 'Advanced Engineering Concepts', 'Mastering Psychology', 'Introduction to Paleontology', 'Introduction to Physics', 'Political Science Essentials', 'Geography for Beginners', 'Mastering Nutrition', 'Introduction to Developmental Psychology', 'Advanced Urban Planning Concepts', 'Introduction to Organizational Behavior', 'Advanced Theater Arts Concepts', 'Mastering Cognitive Science', 'Genetics for Beginners', 'Introduction to Music Composition', 'Introduction to Quantum Computing', 'Mastering Deep Learning', 'Public Health Essentials', 'Introduction to Photography', 'Introduction to Linguistics', 'Introduction to Theater Arts', 'Introduction to Microeconomics', 'Introduction to Social Media Management', 'Mastering Electrical Engineering', 'Robotics for Beginners', 'Urban Planning for Beginners', 'Human Rights for Beginners', 'Mastering Macroeconomics', 'Introduction to Interior Design', 'Materials Science Essentials', 'Education for Beginners', 'Advanced Civil Engineering Concepts', 'Advanced Law Concepts', 'Public Relations Essentials', 'Mastering Information Technology', 'Film Studies Essentials', 'Civil Engineering Essentials', 'Forensic Science for Beginners', 'Medicine for Beginners', 'Game Design Essentials', 'Mastering Brand Management', 'Mastering Art History', 'Introduction to Marketing', 'Mastering Choreography', 'Mechanical Engineering for Beginners', 'Advanced Ethics Concepts', 'Journalism for Beginners', 'Mastering Social Media Management', 'Quantum Mechanics for Beginners', 'Mastering Business Administration', 'Introduction to Mathematics', 'History Essentials', 'Mastering Behavioral Economics', 'Mastering Urban Planning', 'Introduction to Anthropology', 'Introduction to Entrepreneurship', 'Advanced Business Administration Concepts', 'Quantum Computing Essentials', 'Paleontology for Beginners', 'Cultural Studies Essentials', 'Engineering for Beginners', 'Advanced Brand Management Concepts', 'Urban Planning Essentials', 'Mastering Engineering', 'Introduction to History', 'Introduction to Brand Management', 'Mastering Journalism', 'Developmental Psychology Essentials', 'Environmental Science for Beginners', 'Advanced Sociology Concepts', 'Advanced Medicine Concepts', 'Robotics Essentials', 'Advanced History Concepts', 'Marketing for Beginners', 'Architecture Essentials', 'Architecture for Beginners', 'Data Science for Beginners', 'Mastering Marine Biology', 'Advanced Film Studies Concepts', 'Mastering Theater Arts', 'Computer Science for Beginners', 'Introduction to Forensic Science', 'Quantum Mechanics Essentials', 'Mastering Organizational Behavior', 'Introduction to Choreography', 'Introduction to Fashion Design', 'Mastering English Language', 'Mastering Communication Studies', 'Linguistics for Beginners', 'Mastering Education', 'Mastering Paleontology', 'Cultural Studies for Beginners', 'Electrical Engineering Essentials', 'Film Studies for Beginners', 'Music Composition Essentials', 'Mastering Philosophy', 'Advanced Genetics Concepts', 'Mastering Sociology', 'Mastering Music Theory', 'Introduction to Urban Planning', 'Introduction to Culinary Arts', 'Photography Essentials', 'Advanced Graphic Design Concepts', 'Mastering Entrepreneurship', 'Introduction to Human Rights', 'Advanced Aerospace Engineering Concepts', 'Advanced Cognitive Science Concepts', 'Introduction to Sports Science', 'Introduction to Economics', 'Mastering Music Composition', 'Advanced Software Engineering Concepts', 'Mastering Civil Engineering', 'Photography for Beginners', 'Organizational Behavior for Beginners', 'Mastering Cryptocurrency Trading', 'Mastering History', 'Communication Studies for Beginners', 'Introduction to Communication Studies', 'Mastering Agriculture', 'Mastering Film Studies', 'Cryptocurrency Trading for Beginners', 'Mastering Fashion Design', 'Advanced Electrical Engineering Concepts', 'Medicine Essentials', 'History for Beginners', 'Mastering Biology', 'Data Science Essentials', 'Advanced Communication Studies Concepts', 'Advanced Computer Science Concepts', 'Introduction to Linguistic Anthropology', 'Culinary Arts for Beginners', 'Mastering Machine Learning', 'Mastering Industrial Psychology', 'Mastering Literature', 'Introduction to Education', 'Industrial Psychology Essentials', 'Graphic Design for Beginners', 'Mastering Photography', 'Human Resources Management Essentials', 'Introduction to Renewable Energy', 'Music Theory Essentials', 'Introduction to Human Resources Management', 'Mastering Medicine', 'Advanced Game Design Concepts', 'Mastering Political Science', 'Introduction to Macroeconomics', 'Advanced Economics Concepts', 'Game Design for Beginners', 'Mastering Developmental Psychology', 'Advanced Deep Learning Concepts', 'Advanced Cryptography Concepts', 'Mastering Biochemistry', 'Renewable Energy Essentials', 'Microeconomics Essentials', 'Nanotechnology for Beginners', 'Information Technology Essentials', 'Introduction to Psychology', 'Education Essentials', 'Advanced Agriculture Concepts', 'Entrepreneurship Essentials', 'Statistics Essentials', 'Journalism Essentials', 'Introduction to International Relations', 'Chemistry Essentials', 'Advanced Cryptocurrency Trading Concepts', 'Advanced Machine Learning Concepts', 'Advanced Marine Biology Concepts', 'Choreography for Beginners', 'Conflict Resolution for Beginners', 'Mastering Geology', 'Choreography Essentials', 'Introduction to Biology']

subjects = ['Statistics', 'International Relations', 'Marketing', 'Engineering', 'Human Resources Management', 'Civil Engineering', 'Development Studies', 'Physics', 'Conflict Resolution', 'Environmental Science', 'Artificial Intelligence', 'Anthropology', 'Psychology', 'Marine Biology', 'English Language', 'Cognitive Science', 'Chemistry', 'Wilderness Survival', 'Music Theory', 'Geography', 'Social Media Management', 'Law', 'Genetics', 'Computer Science', 'Biology', 'Cryptography', 'Materials Science', 'Geology', 'Sports Science', 'Electrical Engineering', 'Economics', 'Microeconomics', 'Paleontology', 'Nanotechnology', 'Photography', 'Deep Learning', 'Pharmacology', 'Journalism', 'Mechanical Engineering', 'Aerospace Engineering', 'Supply Chain Management', 'Machine Learning', 'Mathematics', 'Game Theory', 'Human Rights', 'Religious Studies', 'Macroeconomics', 'Interior Design', 'Zoology', 'Art History', 'Agriculture', 'Industrial Psychology', 'Theater Arts', 'Ethics', 'Cybersecurity', 'Communication Studies', 'Software Engineering', 'Developmental Psychology', 'Literature', 'Neurobiology', 'Forensic Science', 'Graphic Design', 'Public Relations', 'Medicine', 'Biochemistry', 'Quantum Computing', 'Cryptocurrency', 'Sociology', 'Cultural Studies', 'Astronomy', 'Data Science', 'Behavioral Economics', 'Music Composition', 'Information Technology', 'Robotics', 'Architecture', 'Business Administration', 'Operations Management', 'Philosophy', 'Political Science', 'Nutrition', 'Urban Planning', 'Organizational Behavior', 'Public Health', 'Linguistics', 'Education', 'Film Studies', 'Game Design', 'Brand Management', 'Choreography', 'Quantum Mechanics', 'History', 'Entrepreneurship', 'Fashion Design', 'Culinary Arts', 'Cryptocurrency Trading', 'Linguistic Anthropology', 'Renewable Energy']

user_languages = ['English', 'Spanish', 'French', 'German', 'Chinese', 'Russian']
user_levels = ['Beginner', 'Intermediate', 'Advanced']
online_courses = ['Materials Science Lab', 'Renewable Energy Solutions'
 'Business Administration Bootcamp', 'Chemistry Essentials'
 'Digital Marketing Strategies' ,'Linguistics Lab'
 'Operations Management Mastery', 'Statistical Analysis Workshop'
 'Environmental Science Explorations' ,'Game Design Workshop'
 'Biology Basics', 'Choreography Masterclass' ,'Math Mastery'
 'Astronomy Adventures', 'Urban Planning Insights',
 'Aerospace Engineering Explained' ,'Developmental Psychology Workshop',
 'Civil Engineering Principles', 'Agricultural Innovations',
 'Political Science Crash Course', 'Conflict Resolution Strategies',
 'Game Theory Fundamentals', 'Pharmacology Insights' ,'Geology Discovery',
 'Electrical Engineering Essentials', 'Music Composition Techniques',
 'Cognitive Science Explorations', 'Forensic Science Fundamentals',
 'Cultural Anthropology Guide', 'Graphic Design Masterclass',
 'Sociology Insights', 'Coding for Beginners', 'Art History Journey',
 'Supply Chain Management Workshop', 'Literary Classics Review',
 'Mechanical Engineering Workshop' ,'Nanotechnology Explorations',
 'World History Explained', 'Cryptocurrency Basics',
 'Ethical Dilemmas Seminar' ,'Biochemistry Bootcamp' ,'Psychology 101',
 'Economic Principles', 'Neurobiology Essentials', 'Physics Fundamentals',
 'Fashion Design Studio', 'Philosophical Thinking' ,'Global Geography Tour',
 'English Grammar Workshop', 'Cybersecurity Essentials']
suggested_apps = ['ElectriEdu' , 'CognoCraft', 'MusicMagic', 'MateriMagic', 'CodeCraft',
 'CultAnthro' ,'BioBuddy', 'GameGenius', 'DigitalMark', 'LitLearn', 'EthicEase',
 'Histopedia', 'NeuroNest', 'PoliSciPro' ,'SupplySense', 'EconEase', 'DevPsych',
 'AeroEdu', 'ConflictCoach', 'NanoNexus', 'SociStudy', 'BioBlitz',
 'ChemConnect', 'RenewTech' ,'AstroAdvent' ,'ForenTech', 'Fashionista',
 'EngLang', 'GeoGuru' ,'AgriApp', 'PhysicsExplorer', 'UrbanPlanner',
 'GameTactics', 'ChoreoCraft', 'StatMaster' ,'PhiloForum' ,'OpMan',
 'ArtHistoria' ,'LinguaLab', 'CivilEssence' ,'PsychPal', 'GeoExplorer',
 'MathGenius', 'PharmaPedia', 'GraphiGenius' 'EnviroEdu', 'BizBoost',
 'MechMaster' ,'CyberSecPro', 'CryptoCraze']
# Generate random data
num_rows = 1000
data = {
    'Subject': np.random.choice(subjects, num_rows),
    'User_Language': np.random.choice(user_languages, num_rows),
    'User_Level': np.random.choice(user_levels, num_rows),
    'Text_Book': np.random.choice(text_books, num_rows),
    'Online_Course': np.random.choice(online_courses, num_rows),
    'Suggested_App': np.random.choice(suggested_apps, num_rows)
}

# Create DataFrame
df3 = pd.DataFrame(data)

# Display the DataFrame
df3
# Out:
#                      Subject User_Language    User_Level  \
# 0                Game Theory       Spanish      Beginner
# 1                    Physics       English      Beginner
# 2                 Psychology       Spanish      Advanced
# 3           Cultural Studies        French      Advanced
# 4     Electrical Engineering        German      Advanced
# ..                       ...           ...           ...
# 995             Paleontology       Russian      Advanced
# 996  Supply Chain Management       Russian  Intermediate
# 997                Economics       English      Beginner
# 998               Philosophy       Russian      Advanced
# 999   Mechanical Engineering       English      Advanced
#
#                                Text_Book  \
# 0                   Ethics for Beginners
# 1          Advanced Photography Concepts
# 2       Introduction to Entrepreneurship
# 3                 Mastering Theater Arts
# 4             Architecture for Beginners
# ...

# %%
import  pandas as pd
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
df1=pd.read_csv("educational_resource_dataset.csv")

# %%
df1
# Out:
#                                           Title  \
# 0                  Advanced Statistics Concepts
# 1     Advanced International Relations Concepts
# 2                           Mastering Marketing
# 3                           Mastering Marketing
# 4                           Mastering Marketing
# ...                                         ...
# 1660                    Introduction to Biology
# 1661         Advanced Cultural Studies Concepts
# 1662                  Introduction to Education
# 1663                   Mastering Urban Planning
# 1664          Mastering Organizational Behavior
#
#                                             Description     Author/Instructor  \
# 0                  A comprehensive guide to Statistics.  Christopher Anderson
# 1     A comprehensive guide to International Relations.        Michael Wilson
# 2                   A comprehensive guide to Marketing.         David Johnson
# ...

# %%
unique_elements = df1['Educational Apps'].unique()
print(unique_elements)
# Out:
# ['ElectriEdu' 'CognoCraft' 'MusicMagic' 'MateriMagic' 'CodeCraft'
#  'CultAnthro' 'BioBuddy' 'GameGenius' 'DigitalMark' 'LitLearn' 'EthicEase'
#  'Histopedia' 'NeuroNest' 'PoliSciPro' 'SupplySense' 'EconEase' 'DevPsych'
#  'AeroEdu' 'ConflictCoach' 'NanoNexus' 'SociStudy' 'BioBlitz'
#  'ChemConnect' 'RenewTech' 'AstroAdvent' 'ForenTech' 'Fashionista'
#  'EngLang' 'GeoGuru' 'AgriApp' 'PhysicsExplorer' 'UrbanPlanner'
#  'GameTactics' 'ChoreoCraft' 'StatMaster' 'PhiloForum' 'OpMan'
#  'ArtHistoria' 'LinguaLab' 'CivilEssence' 'PsychPal' 'GeoExplorer'
#  'MathGenius' 'PharmaPedia' 'GraphiGenius' 'EnviroEdu' 'BizBoost'
#  'MechMaster' 'CyberSecPro' 'CryptoCraze']

# %% [markdown]
# # EDA:-EXPLOARATORY DATA  ANALYSIS

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1665 entries, 0 to 1664
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              1665 non-null   object
#  1   Description        1665 non-null   object
#  2   Author/Instructor  1665 non-null   object
#  3   Topic/Subject      1665 non-null   object
#  4   Reviews            1665 non-null   float64
#  5   Tags/Keywords      1665 non-null   object
#  6   Publication Year   1665 non-null   int64
#  7   Online Courses     1665 non-null   object
#  8   Educational Apps   1665 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 117.2+ KB

# %%
df1.isnull().sum()
# Out:
# Title                0
# Description          0
# Author/Instructor    0
# Topic/Subject        0
# Reviews              0
# Tags/Keywords        0
# Publication Year     0
# Online Courses       0
# Educational Apps     0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 6

# %%
df1.nunique()
# Out:
# Title                297
# Description           98
# Author/Instructor     10
# Topic/Subject         98
# Reviews               98
# Tags/Keywords         98
# Publication Year      23
# Online Courses        50
# Educational Apps      50
# dtype: int64

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of                                           Title  \
# 0                  Advanced Statistics Concepts
# 1     Advanced International Relations Concepts
# 2                           Mastering Marketing
# 3                           Mastering Marketing
# 4                           Mastering Marketing
# ...                                         ...
# 1660                    Introduction to Biology
# 1661         Advanced Cultural Studies Concepts
# 1662                  Introduction to Education
# 1663                   Mastering Urban Planning
# 1664          Mastering Organizational Behavior
#
#                                             Description     Author/Instructor  \
# 0                  A comprehensive guide to Statistics.  Christopher Anderson
# 1     A comprehensive guide to International Relations.        Michael Wilson
# 2                   A comprehensive guide to Marketing.         David Johnson
# ...

# %% [markdown]
# # # Drop rows with missing values  and  Remove duplicates

# %%
df1.dropna(inplace=True)  # Drop rows with missing values
df1.drop_duplicates(inplace=True)  # Remove duplicates

df1
# Out:
#                                           Title  \
# 0                  Advanced Statistics Concepts
# 1     Advanced International Relations Concepts
# 2                           Mastering Marketing
# 3                           Mastering Marketing
# 4                           Mastering Marketing
# ...                                         ...
# 1660                    Introduction to Biology
# 1661         Advanced Cultural Studies Concepts
# 1662                  Introduction to Education
# 1663                   Mastering Urban Planning
# 1664          Mastering Organizational Behavior
#
#                                             Description     Author/Instructor  \
# 0                  A comprehensive guide to Statistics.  Christopher Anderson
# 1     A comprehensive guide to International Relations.        Michael Wilson
# 2                   A comprehensive guide to Marketing.         David Johnson
# ...

# %% [markdown]
# # Convert categorical columns to integer codes

# %%
# Convert categorical columns to integer codes
categorical_columns = df1.select_dtypes(include='object').columns
df1[categorical_columns] = df1[categorical_columns].astype('category').apply(lambda x: x.cat.codes)

# %%
df1.head(10)
# Out:
#    Title  Description  Author/Instructor  Topic/Subject  Reviews  \
# 0     54           92                  0             92    100.0
# 1     36           52                  8             52     26.0
# 2    231           61                  1             61     23.0
# 3    231           61                  1             61     23.0
# 4    231           61                  1             61     23.0
# 5    231           61                  1             61     23.0
# 6    231           61                  1             61     23.0
# 7    231           61                  1             61     23.0
# 8    231           61                  1             61     23.0
# 9    231           61                  1             61     23.0
#
#    Tags/Keywords  Publication Year  Online Courses  Educational Apps
# 0             92              2005              32                19
# 1             52              2013              44                11
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1659 entries, 0 to 1664
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              1659 non-null   int16
#  1   Description        1659 non-null   int8
#  2   Author/Instructor  1659 non-null   int8
#  3   Topic/Subject      1659 non-null   int8
#  4   Reviews            1659 non-null   float64
#  5   Tags/Keywords      1659 non-null   int8
#  6   Publication Year   1659 non-null   int64
#  7   Online Courses     1659 non-null   int8
#  8   Educational Apps   1659 non-null   int8
# dtypes: float64(1), int16(1), int64(1), int8(6)
# memory usage: 51.8 KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1659 entries, 0 to 1664
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              1659 non-null   int16
#  1   Description        1659 non-null   int8
#  2   Author/Instructor  1659 non-null   int8
#  3   Topic/Subject      1659 non-null   int8
#  4   Reviews            1659 non-null   float64
#  5   Tags/Keywords      1659 non-null   int8
#  6   Publication Year   1659 non-null   int64
#  7   Online Courses     1659 non-null   int8
#  8   Educational Apps   1659 non-null   int8
# dtypes: float64(1), int16(1), int64(1), int8(6)
# memory usage: 51.8 KB

# %%
corr=df1.corr()
corr
# Out:
#                       Title  Description  Author/Instructor  Topic/Subject  \
# Title              1.000000     0.544762           0.003538       0.544516
# Description        0.544762     1.000000           0.002013       0.999985
# Author/Instructor  0.003538     0.002013           1.000000       0.002181
# Topic/Subject      0.544516     0.999985           0.002181       1.000000
# Reviews            0.130626     0.112722          -0.043980       0.112597
# Tags/Keywords      0.544516     0.999985           0.002181       1.000000
# Publication Year   0.096767     0.131875          -0.048916       0.132250
# Online Courses    -0.005527    -0.003511           0.001098      -0.003636
# Educational Apps   0.015301     0.046717          -0.015156       0.046818
#
#                     Reviews  Tags/Keywords  Publication Year  Online Courses  \
# Title              0.130626       0.544516          0.096767       -0.005527
# ...

# %%
import pandas as pd
import numpy as np

# Define the lists of information
text_books = ['Advanced Statistics Concepts', 'Advanced International Relations Concepts', 'Mastering Marketing', 'Introduction to Engineering', 'Mastering Human Resources Management', 'Introduction to Civil Engineering', 'Advanced Development Studies Concepts', 'Mastering Physics', 'Mastering Conflict Resolution', 'Advanced Environmental Science Concepts', 'Artificial Intelligence for Beginners', 'Anthropology for Beginners', 'Psychology for Beginners', 'Marine Biology for Beginners', 'Advanced English Language Concepts', 'Introduction to Cognitive Science', 'Mastering Chemistry', 'International Relations Essentials', 'Mastering Wilderness Survival', 'Music Theory for Beginners', 'Geography Essentials', 'Advanced Social Media Management Concepts', 'Introduction to Law', 'Introduction to Wilderness Survival', 'Introduction to Geography', 'Introduction to Genetics', 'Mastering Computer Science', 'Conflict Resolution Essentials', 'Biology Essentials', 'Cryptography for Beginners', 'Materials Science for Beginners', 'Geology Essentials', 'Sports Science Essentials', 'Law Essentials', 'Civil Engineering for Beginners', 'Electrical Engineering for Beginners', 'Mastering Economics', 'Mastering Microeconomics', 'Advanced Paleontology Concepts', 'Nanotechnology Essentials', 'Advanced Photography Concepts', 'Wilderness Survival for Beginners', 'Introduction to Development Studies', 'Geology for Beginners', 'Deep Learning Essentials', 'Introduction to Pharmacology', 'Advanced Journalism Concepts', 'Environmental Science Essentials', 'Wilderness Survival Essentials', 'Mechanical Engineering Essentials', 'Aerospace Engineering for Beginners', 'Introduction to Supply Chain Management', 'Paleontology Essentials', 'Advanced Conflict Resolution Concepts', 'Machine Learning Essentials', 'Mastering Mathematics', 'Advanced Game Theory Concepts', 'Mastering Human Rights', 'Advanced Religious Studies Concepts', 'Macroeconomics for Beginners', 'Advanced Interior Design Concepts', 'Zoology for Beginners', 'Art History Essentials', 'Agriculture Essentials', 'Advanced Industrial Psychology Concepts', 'Introduction to Materials Science', 'Theater Arts Essentials', 'Ethics for Beginners', 'Mastering Cybersecurity', 'Physics for Beginners', 'Communication Studies Essentials', 'Mastering Statistics', 'Software Engineering Essentials', 'Advanced Developmental Psychology Concepts', 'Introduction to Journalism', 'Literature Essentials', 'Neurobiology Essentials', 'Advanced Sports Science Concepts', 'Advanced Forensic Science Concepts', 'Graphic Design Essentials', 'Cognitive Science Essentials', 'Public Relations for Beginners', 'Introduction to Medicine', 'Biochemistry for Beginners', 'Mastering Pharmacology', 'Introduction to Public Relations', 'Advanced Human Resources Management Concepts', 'Quantum Computing for Beginners', 'Introduction to Neurobiology', 'Introduction to Artificial Intelligence', 'Introduction to Literature', 'Introduction to Cryptocurrency', 'Sociology Essentials', 'Mastering Anthropology', 'Mastering Cultural Studies', 'Astronomy for Beginners', 'Introduction to Data Science', 'Advanced Behavioral Economics Concepts', 'Advanced Marketing Concepts', 'Religious Studies for Beginners', 'Art History for Beginners', 'Mastering Environmental Science', 'Supply Chain Management for Beginners', 'Mastering Ethics', 'Advanced Music Composition Concepts', 'Introduction to Music Theory', 'Biochemistry Essentials', 'Advanced Physics Concepts', 'Mastering Forensic Science', 'Introduction to Information Technology', 'Introduction to Robotics', 'Mastering Cryptography', 'Advanced Chemistry Concepts', 'Advanced Architecture Concepts', 'Advanced Cultural Studies Concepts', 'Business Administration for Beginners', 'Introduction to Statistics', 'Advanced Anthropology Concepts', 'Mastering Operations Management', 'Advanced Data Science Concepts', 'Biology for Beginners', 'Zoology Essentials', 'Advanced Macroeconomics Concepts', 'Mastering Astronomy', 'Advanced Philosophy Concepts', 'Astronomy Essentials', 'Advanced Engineering Concepts', 'Mastering Psychology', 'Introduction to Paleontology', 'Introduction to Physics', 'Political Science Essentials', 'Geography for Beginners', 'Mastering Nutrition', 'Introduction to Developmental Psychology', 'Advanced Urban Planning Concepts', 'Introduction to Organizational Behavior', 'Advanced Theater Arts Concepts', 'Mastering Cognitive Science', 'Genetics for Beginners', 'Introduction to Music Composition', 'Introduction to Quantum Computing', 'Mastering Deep Learning', 'Public Health Essentials', 'Introduction to Photography', 'Introduction to Linguistics', 'Introduction to Theater Arts', 'Introduction to Microeconomics', 'Introduction to Social Media Management', 'Mastering Electrical Engineering', 'Robotics for Beginners', 'Urban Planning for Beginners', 'Human Rights for Beginners', 'Mastering Macroeconomics', 'Introduction to Interior Design', 'Materials Science Essentials', 'Education for Beginners', 'Advanced Civil Engineering Concepts', 'Advanced Law Concepts', 'Public Relations Essentials', 'Mastering Information Technology', 'Film Studies Essentials', 'Civil Engineering Essentials', 'Forensic Science for Beginners', 'Medicine for Beginners', 'Game Design Essentials', 'Mastering Brand Management', 'Mastering Art History', 'Introduction to Marketing', 'Mastering Choreography', 'Mechanical Engineering for Beginners', 'Advanced Ethics Concepts', 'Journalism for Beginners', 'Mastering Social Media Management', 'Quantum Mechanics for Beginners', 'Mastering Business Administration', 'Introduction to Mathematics', 'History Essentials', 'Mastering Behavioral Economics', 'Mastering Urban Planning', 'Introduction to Anthropology', 'Introduction to Entrepreneurship', 'Advanced Business Administration Concepts', 'Quantum Computing Essentials', 'Paleontology for Beginners', 'Cultural Studies Essentials', 'Engineering for Beginners', 'Advanced Brand Management Concepts', 'Urban Planning Essentials', 'Mastering Engineering', 'Introduction to History', 'Introduction to Brand Management', 'Mastering Journalism', 'Developmental Psychology Essentials', 'Environmental Science for Beginners', 'Advanced Sociology Concepts', 'Advanced Medicine Concepts', 'Robotics Essentials', 'Advanced History Concepts', 'Marketing for Beginners', 'Architecture Essentials', 'Architecture for Beginners', 'Data Science for Beginners', 'Mastering Marine Biology', 'Advanced Film Studies Concepts', 'Mastering Theater Arts', 'Computer Science for Beginners', 'Introduction to Forensic Science', 'Quantum Mechanics Essentials', 'Mastering Organizational Behavior', 'Introduction to Choreography', 'Introduction to Fashion Design', 'Mastering English Language', 'Mastering Communication Studies', 'Linguistics for Beginners', 'Mastering Education', 'Mastering Paleontology', 'Cultural Studies for Beginners', 'Electrical Engineering Essentials', 'Film Studies for Beginners', 'Music Composition Essentials', 'Mastering Philosophy', 'Advanced Genetics Concepts', 'Mastering Sociology', 'Mastering Music Theory', 'Introduction to Urban Planning', 'Introduction to Culinary Arts', 'Photography Essentials', 'Advanced Graphic Design Concepts', 'Mastering Entrepreneurship', 'Introduction to Human Rights', 'Advanced Aerospace Engineering Concepts', 'Advanced Cognitive Science Concepts', 'Introduction to Sports Science', 'Introduction to Economics', 'Mastering Music Composition', 'Advanced Software Engineering Concepts', 'Mastering Civil Engineering', 'Photography for Beginners', 'Organizational Behavior for Beginners', 'Mastering Cryptocurrency Trading', 'Mastering History', 'Communication Studies for Beginners', 'Introduction to Communication Studies', 'Mastering Agriculture', 'Mastering Film Studies', 'Cryptocurrency Trading for Beginners', 'Mastering Fashion Design', 'Advanced Electrical Engineering Concepts', 'Medicine Essentials', 'History for Beginners', 'Mastering Biology', 'Data Science Essentials', 'Advanced Communication Studies Concepts', 'Advanced Computer Science Concepts', 'Introduction to Linguistic Anthropology', 'Culinary Arts for Beginners', 'Mastering Machine Learning', 'Mastering Industrial Psychology', 'Mastering Literature', 'Introduction to Education', 'Industrial Psychology Essentials', 'Graphic Design for Beginners', 'Mastering Photography', 'Human Resources Management Essentials', 'Introduction to Renewable Energy', 'Music Theory Essentials', 'Introduction to Human Resources Management', 'Mastering Medicine', 'Advanced Game Design Concepts', 'Mastering Political Science', 'Introduction to Macroeconomics', 'Advanced Economics Concepts', 'Game Design for Beginners', 'Mastering Developmental Psychology', 'Advanced Deep Learning Concepts', 'Advanced Cryptography Concepts', 'Mastering Biochemistry', 'Renewable Energy Essentials', 'Microeconomics Essentials', 'Nanotechnology for Beginners', 'Information Technology Essentials', 'Introduction to Psychology', 'Education Essentials', 'Advanced Agriculture Concepts', 'Entrepreneurship Essentials', 'Statistics Essentials', 'Journalism Essentials', 'Introduction to International Relations', 'Chemistry Essentials', 'Advanced Cryptocurrency Trading Concepts', 'Advanced Machine Learning Concepts', 'Advanced Marine Biology Concepts', 'Choreography for Beginners', 'Conflict Resolution for Beginners', 'Mastering Geology', 'Choreography Essentials', 'Introduction to Biology']

subjects = ['Statistics', 'International Relations', 'Marketing', 'Engineering', 'Human Resources Management', 'Civil Engineering', 'Development Studies', 'Physics', 'Conflict Resolution', 'Environmental Science', 'Artificial Intelligence', 'Anthropology', 'Psychology', 'Marine Biology', 'English Language', 'Cognitive Science', 'Chemistry', 'Wilderness Survival', 'Music Theory', 'Geography', 'Social Media Management', 'Law', 'Genetics', 'Computer Science', 'Biology', 'Cryptography', 'Materials Science', 'Geology', 'Sports Science', 'Electrical Engineering', 'Economics', 'Microeconomics', 'Paleontology', 'Nanotechnology', 'Photography', 'Deep Learning', 'Pharmacology', 'Journalism', 'Mechanical Engineering', 'Aerospace Engineering', 'Supply Chain Management', 'Machine Learning', 'Mathematics', 'Game Theory', 'Human Rights', 'Religious Studies', 'Macroeconomics', 'Interior Design', 'Zoology', 'Art History', 'Agriculture', 'Industrial Psychology', 'Theater Arts', 'Ethics', 'Cybersecurity', 'Communication Studies', 'Software Engineering', 'Developmental Psychology', 'Literature', 'Neurobiology', 'Forensic Science', 'Graphic Design', 'Public Relations', 'Medicine', 'Biochemistry', 'Quantum Computing', 'Cryptocurrency', 'Sociology', 'Cultural Studies', 'Astronomy', 'Data Science', 'Behavioral Economics', 'Music Composition', 'Information Technology', 'Robotics', 'Architecture', 'Business Administration', 'Operations Management', 'Philosophy', 'Political Science', 'Nutrition', 'Urban Planning', 'Organizational Behavior', 'Public Health', 'Linguistics', 'Education', 'Film Studies', 'Game Design', 'Brand Management', 'Choreography', 'Quantum Mechanics', 'History', 'Entrepreneurship', 'Fashion Design', 'Culinary Arts', 'Cryptocurrency Trading', 'Linguistic Anthropology', 'Renewable Energy']

user_languages = ['English', 'Spanish', 'French', 'German', 'Chinese', 'Russian']
user_levels = ['Beginner', 'Intermediate', 'Advanced']
online_courses = ['Materials Science Lab', 'Renewable Energy Solutions'
 'Business Administration Bootcamp', 'Chemistry Essentials'
 'Digital Marketing Strategies' ,'Linguistics Lab'
 'Operations Management Mastery', 'Statistical Analysis Workshop'
 'Environmental Science Explorations' ,'Game Design Workshop'
 'Biology Basics', 'Choreography Masterclass' ,'Math Mastery'
 'Astronomy Adventures', 'Urban Planning Insights',
 'Aerospace Engineering Explained' ,'Developmental Psychology Workshop',
 'Civil Engineering Principles', 'Agricultural Innovations',
 'Political Science Crash Course', 'Conflict Resolution Strategies',
 'Game Theory Fundamentals', 'Pharmacology Insights' ,'Geology Discovery',
 'Electrical Engineering Essentials', 'Music Composition Techniques',
 'Cognitive Science Explorations', 'Forensic Science Fundamentals',
 'Cultural Anthropology Guide', 'Graphic Design Masterclass',
 'Sociology Insights', 'Coding for Beginners', 'Art History Journey',
 'Supply Chain Management Workshop', 'Literary Classics Review',
 'Mechanical Engineering Workshop' ,'Nanotechnology Explorations',
 'World History Explained', 'Cryptocurrency Basics',
 'Ethical Dilemmas Seminar' ,'Biochemistry Bootcamp' ,'Psychology 101',
 'Economic Principles', 'Neurobiology Essentials', 'Physics Fundamentals',
 'Fashion Design Studio', 'Philosophical Thinking' ,'Global Geography Tour',
 'English Grammar Workshop', 'Cybersecurity Essentials']
suggested_apps = ['ElectriEdu' , 'CognoCraft', 'MusicMagic', 'MateriMagic', 'CodeCraft',
 'CultAnthro' ,'BioBuddy', 'GameGenius', 'DigitalMark', 'LitLearn', 'EthicEase',
 'Histopedia', 'NeuroNest', 'PoliSciPro' ,'SupplySense', 'EconEase', 'DevPsych',
 'AeroEdu', 'ConflictCoach', 'NanoNexus', 'SociStudy', 'BioBlitz',
 'ChemConnect', 'RenewTech' ,'AstroAdvent' ,'ForenTech', 'Fashionista',
 'EngLang', 'GeoGuru' ,'AgriApp', 'PhysicsExplorer', 'UrbanPlanner',
 'GameTactics', 'ChoreoCraft', 'StatMaster' ,'PhiloForum' ,'OpMan',
 'ArtHistoria' ,'LinguaLab', 'CivilEssence' ,'PsychPal', 'GeoExplorer',
 'MathGenius', 'PharmaPedia', 'GraphiGenius' 'EnviroEdu', 'BizBoost',
 'MechMaster' ,'CyberSecPro', 'CryptoCraze']
# Generate random data
num_rows = 1000
data = {
    'Subject': np.random.choice(subjects, num_rows),
    'User_Language': np.random.choice(user_languages, num_rows),
    'User_Level': np.random.choice(user_levels, num_rows),
    'Text_Book': np.random.choice(text_books, num_rows),
    'Online_Course': np.random.choice(online_courses, num_rows),
    'Suggested_App': np.random.choice(suggested_apps, num_rows)
}

# Create DataFrame
data = pd.DataFrame(data)

# Display the DataFrame
data
# Out:
#                       Subject User_Language    User_Level  \
# 0                      Ethics       Chinese  Intermediate
# 1                  Journalism       English      Beginner
# 2             Interior Design        German      Advanced
# 3     Supply Chain Management        German      Beginner
# 4    Developmental Psychology       English      Beginner
# ..                        ...           ...           ...
# 995              Human Rights        German      Beginner
# 996         Quantum Mechanics       Russian  Intermediate
# 997         Religious Studies       English      Advanced
# 998           Interior Design       Spanish      Beginner
# 999                 Chemistry        German  Intermediate
#
#                                      Text_Book  \
# 0                       Mastering Anthropology
# 1                      Astronomy for Beginners
# 2    Advanced Social Media Management Concepts
# 3               Advanced Data Science Concepts
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Subject        1000 non-null   object
#  1   User_Language  1000 non-null   object
#  2   User_Level     1000 non-null   object
#  3   Text_Book      1000 non-null   object
#  4   Online_Course  1000 non-null   object
#  5   Suggested_App  1000 non-null   object
# dtypes: object(6)
# memory usage: 47.0+ KB

# %%
data.isnull().sum()
# Out:
# Subject          0
# User_Language    0
# User_Level       0
# Text_Book        0
# Online_Course    0
# Suggested_App    0
# dtype: int64

# %%
data.describe()
# Out:
#                         Subject User_Language    User_Level  \
# count                      1000          1000          1000
# unique                       98             6             3
# top     Supply Chain Management       English  Intermediate
# freq                         21           185           343
#
#                     Text_Book  \
# count                    1000
# unique                    283
# top     Statistics Essentials
# freq                        8
#
#                                             Online_Course Suggested_App
# count                                                1000          1000
# unique                                                 44            49
# top     Statistical Analysis WorkshopEnvironmental Sci...   GeoExplorer
# freq                                                   33            28

# %%
# # Convert categorical columns to integer codes
# categorical_columns = data.select_dtypes(include='object').columns
# data[categorical_columns] = data[categorical_columns].astype('category').apply(lambda x: x.cat.codes)

# %%
# df2=pd.DataFrame(data) 
# df2

# %%
# df2.info()

# %%
 data
# Out:
#                       Subject User_Language    User_Level  \
# 0                      Ethics       Chinese  Intermediate
# 1                  Journalism       English      Beginner
# 2             Interior Design        German      Advanced
# 3     Supply Chain Management        German      Beginner
# 4    Developmental Psychology       English      Beginner
# ..                        ...           ...           ...
# 995              Human Rights        German      Beginner
# 996         Quantum Mechanics       Russian  Intermediate
# 997         Religious Studies       English      Advanced
# 998           Interior Design       Spanish      Beginner
# 999                 Chemistry        German  Intermediate
#
#                                      Text_Book  \
# 0                       Mastering Anthropology
# 1                      Astronomy for Beginners
# 2    Advanced Social Media Management Concepts
# 3               Advanced Data Science Concepts
# ...

# %%
import pandas as pd
import numpy as np

# Define the categories for each column
subjects = ['Statistics', 'International Relations', 'Marketing', 'Engineering', 'Human Resources Management', 'Civil Engineering', 'Development Studies', 'Physics', 'Conflict Resolution', 'Environmental Science', 'Artificial Intelligence', 'Anthropology', 'Psychology', 'Marine Biology', 'English Language', 'Cognitive Science', 'Chemistry', 'Wilderness Survival', 'Music Theory', 'Geography', 'Social Media Management', 'Law', 'Genetics', 'Computer Science', 'Biology', 'Cryptography', 'Materials Science', 'Geology', 'Sports Science', 'Electrical Engineering', 'Economics', 'Microeconomics', 'Paleontology', 'Nanotechnology', 'Photography', 'Deep Learning', 'Pharmacology', 'Journalism', 'Mechanical Engineering', 'Aerospace Engineering', 'Supply Chain Management', 'Machine Learning', 'Mathematics', 'Game Theory', 'Human Rights', 'Religious Studies', 'Macroeconomics', 'Interior Design', 'Zoology', 'Art History', 'Agriculture', 'Industrial Psychology', 'Theater Arts', 'Ethics', 'Cybersecurity', 'Communication Studies', 'Software Engineering', 'Developmental Psychology', 'Literature', 'Neurobiology', 'Forensic Science', 'Graphic Design', 'Public Relations', 'Medicine', 'Biochemistry', 'Quantum Computing', 'Cryptocurrency', 'Sociology', 'Cultural Studies', 'Astronomy', 'Data Science', 'Behavioral Economics', 'Music Composition', 'Information Technology', 'Robotics', 'Architecture', 'Business Administration', 'Operations Management', 'Philosophy', 'Political Science', 'Nutrition', 'Urban Planning', 'Organizational Behavior', 'Public Health', 'Linguistics', 'Education', 'Film Studies', 'Game Design', 'Brand Management', 'Choreography', 'Quantum Mechanics', 'History', 'Entrepreneurship', 'Fashion Design', 'Culinary Arts', 'Cryptocurrency Trading', 'Linguistic Anthropology', 'Renewable Energy']
user_languages = ['English', 'Spanish', 'French', 'German', 'Chinese', 'Russian']
user_levels = ['Beginner', 'Intermediate', 'Advanced']

text_books = ['Advanced Statistics Concepts', 'Advanced International Relations Concepts', 'Mastering Marketing', 'Introduction to Engineering', 'Mastering Human Resources Management', 'Introduction to Civil Engineering', 'Advanced Development Studies Concepts', 'Mastering Physics', 'Mastering Conflict Resolution', 'Advanced Environmental Science Concepts', 'Artificial Intelligence for Beginners', 'Anthropology for Beginners', 'Psychology for Beginners', 'Marine Biology for Beginners', 'Advanced English Language Concepts', 'Introduction to Cognitive Science', 'Mastering Chemistry', 'International Relations Essentials', 'Mastering Wilderness Survival', 'Music Theory for Beginners', 'Geography Essentials', 'Advanced Social Media Management Concepts', 'Introduction to Law', 'Introduction to Wilderness Survival', 'Introduction to Geography', 'Introduction to Genetics', 'Mastering Computer Science', 'Conflict Resolution Essentials', 'Biology Essentials', 'Cryptography for Beginners', 'Materials Science for Beginners', 'Geology Essentials', 'Sports Science Essentials', 'Law Essentials', 'Civil Engineering for Beginners', 'Electrical Engineering for Beginners', 'Mastering Economics', 'Mastering Microeconomics', 'Advanced Paleontology Concepts', 'Nanotechnology Essentials', 'Advanced Photography Concepts', 'Wilderness Survival for Beginners', 'Introduction to Development Studies', 'Geology for Beginners', 'Deep Learning Essentials', 'Introduction to Pharmacology', 'Advanced Journalism Concepts', 'Environmental Science Essentials', 'Wilderness Survival Essentials', 'Mechanical Engineering Essentials', 'Aerospace Engineering for Beginners', 'Introduction to Supply Chain Management', 'Paleontology Essentials', 'Advanced Conflict Resolution Concepts', 'Machine Learning Essentials', 'Mastering Mathematics', 'Advanced Game Theory Concepts', 'Mastering Human Rights', 'Advanced Religious Studies Concepts', 'Macroeconomics for Beginners', 'Advanced Interior Design Concepts', 'Zoology for Beginners', 'Art History Essentials', 'Agriculture Essentials', 'Advanced Industrial Psychology Concepts', 'Introduction to Materials Science', 'Theater Arts Essentials', 'Ethics for Beginners', 'Mastering Cybersecurity', 'Physics for Beginners', 'Communication Studies Essentials', 'Mastering Statistics', 'Software Engineering Essentials', 'Advanced Developmental Psychology Concepts', 'Introduction to Journalism', 'Literature Essentials', 'Neurobiology Essentials', 'Advanced Sports Science Concepts', 'Advanced Forensic Science Concepts', 'Graphic Design Essentials', 'Cognitive Science Essentials', 'Public Relations for Beginners', 'Introduction to Medicine', 'Biochemistry for Beginners', 'Mastering Pharmacology', 'Introduction to Public Relations', 'Advanced Human Resources Management Concepts', 'Quantum Computing for Beginners', 'Introduction to Neurobiology', 'Introduction to Artificial Intelligence', 'Introduction to Literature', 'Introduction to Cryptocurrency', 'Sociology Essentials', 'Mastering Anthropology', 'Mastering Cultural Studies', 'Astronomy for Beginners', 'Introduction to Data Science', 'Advanced Behavioral Economics Concepts', 'Advanced Marketing Concepts', 'Religious Studies for Beginners', 'Art History for Beginners', 'Mastering Environmental Science', 'Supply Chain Management for Beginners', 'Mastering Ethics', 'Advanced Music Composition Concepts', 'Introduction to Music Theory', 'Biochemistry Essentials', 'Advanced Physics Concepts', 'Mastering Forensic Science', 'Introduction to Information Technology', 'Introduction to Robotics', 'Mastering Cryptography', 'Advanced Chemistry Concepts', 'Advanced Architecture Concepts', 'Advanced Cultural Studies Concepts', 'Business Administration for Beginners', 'Introduction to Statistics', 'Advanced Anthropology Concepts', 'Mastering Operations Management', 'Advanced Data Science Concepts', 'Biology for Beginners', 'Zoology Essentials', 'Advanced Macroeconomics Concepts', 'Mastering Astronomy', 'Advanced Philosophy Concepts', 'Astronomy Essentials', 'Advanced Engineering Concepts', 'Mastering Psychology', 'Introduction to Paleontology', 'Introduction to Physics', 'Political Science Essentials', 'Geography for Beginners', 'Mastering Nutrition', 'Introduction to Developmental Psychology', 'Advanced Urban Planning Concepts', 'Introduction to Organizational Behavior', 'Advanced Theater Arts Concepts', 'Mastering Cognitive Science', 'Genetics for Beginners', 'Introduction to Music Composition', 'Introduction to Quantum Computing', 'Mastering Deep Learning', 'Public Health Essentials', 'Introduction to Photography', 'Introduction to Linguistics', 'Introduction to Theater Arts', 'Introduction to Microeconomics', 'Introduction to Social Media Management', 'Mastering Electrical Engineering', 'Robotics for Beginners', 'Urban Planning for Beginners', 'Human Rights for Beginners', 'Mastering Macroeconomics', 'Introduction to Interior Design', 'Materials Science Essentials', 'Education for Beginners', 'Advanced Civil Engineering Concepts', 'Advanced Law Concepts', 'Public Relations Essentials', 'Mastering Information Technology', 'Film Studies Essentials', 'Civil Engineering Essentials', 'Forensic Science for Beginners', 'Medicine for Beginners', 'Game Design Essentials', 'Mastering Brand Management', 'Mastering Art History', 'Introduction to Marketing', 'Mastering Choreography', 'Mechanical Engineering for Beginners', 'Advanced Ethics Concepts', 'Journalism for Beginners', 'Mastering Social Media Management', 'Quantum Mechanics for Beginners', 'Mastering Business Administration', 'Introduction to Mathematics', 'History Essentials', 'Mastering Behavioral Economics', 'Mastering Urban Planning', 'Introduction to Anthropology', 'Introduction to Entrepreneurship', 'Advanced Business Administration Concepts', 'Quantum Computing Essentials', 'Paleontology for Beginners', 'Cultural Studies Essentials', 'Engineering for Beginners', 'Advanced Brand Management Concepts', 'Urban Planning Essentials', 'Mastering Engineering', 'Introduction to History', 'Introduction to Brand Management', 'Mastering Journalism', 'Developmental Psychology Essentials', 'Environmental Science for Beginners', 'Advanced Sociology Concepts', 'Advanced Medicine Concepts', 'Robotics Essentials', 'Advanced History Concepts', 'Marketing for Beginners', 'Architecture Essentials', 'Architecture for Beginners', 'Data Science for Beginners', 'Mastering Marine Biology', 'Advanced Film Studies Concepts', 'Mastering Theater Arts', 'Computer Science for Beginners', 'Introduction to Forensic Science', 'Quantum Mechanics Essentials', 'Mastering Organizational Behavior', 'Introduction to Choreography', 'Introduction to Fashion Design', 'Mastering English Language', 'Mastering Communication Studies', 'Linguistics for Beginners', 'Mastering Education', 'Mastering Paleontology', 'Cultural Studies for Beginners', 'Electrical Engineering Essentials', 'Film Studies for Beginners', 'Music Composition Essentials', 'Mastering Philosophy', 'Advanced Genetics Concepts', 'Mastering Sociology', 'Mastering Music Theory', 'Introduction to Urban Planning', 'Introduction to Culinary Arts', 'Photography Essentials', 'Advanced Graphic Design Concepts', 'Mastering Entrepreneurship', 'Introduction to Human Rights', 'Advanced Aerospace Engineering Concepts', 'Advanced Cognitive Science Concepts', 'Introduction to Sports Science', 'Introduction to Economics', 'Mastering Music Composition', 'Advanced Software Engineering Concepts', 'Mastering Civil Engineering', 'Photography for Beginners', 'Organizational Behavior for Beginners', 'Mastering Cryptocurrency Trading', 'Mastering History', 'Communication Studies for Beginners', 'Introduction to Communication Studies', 'Mastering Agriculture', 'Mastering Film Studies', 'Cryptocurrency Trading for Beginners', 'Mastering Fashion Design', 'Advanced Electrical Engineering Concepts', 'Medicine Essentials', 'History for Beginners', 'Mastering Biology', 'Data Science Essentials', 'Advanced Communication Studies Concepts', 'Advanced Computer Science Concepts', 'Introduction to Linguistic Anthropology', 'Culinary Arts for Beginners', 'Mastering Machine Learning', 'Mastering Industrial Psychology', 'Mastering Literature', 'Introduction to Education', 'Industrial Psychology Essentials', 'Graphic Design for Beginners', 'Mastering Photography', 'Human Resources Management Essentials', 'Introduction to Renewable Energy', 'Music Theory Essentials', 'Introduction to Human Resources Management', 'Mastering Medicine', 'Advanced Game Design Concepts', 'Mastering Political Science', 'Introduction to Macroeconomics', 'Advanced Economics Concepts', 'Game Design for Beginners', 'Mastering Developmental Psychology', 'Advanced Deep Learning Concepts', 'Advanced Cryptography Concepts', 'Mastering Biochemistry', 'Renewable Energy Essentials', 'Microeconomics Essentials', 'Nanotechnology for Beginners', 'Information Technology Essentials', 'Introduction to Psychology', 'Education Essentials', 'Advanced Agriculture Concepts', 'Entrepreneurship Essentials', 'Statistics Essentials', 'Journalism Essentials', 'Introduction to International Relations', 'Chemistry Essentials', 'Advanced Cryptocurrency Trading Concepts', 'Advanced Machine Learning Concepts', 'Advanced Marine Biology Concepts', 'Choreography for Beginners', 'Conflict Resolution for Beginners', 'Mastering Geology', 'Choreography Essentials', 'Introduction to Biology']
online_courses = ['Materials Science Lab', 'Renewable Energy Solutions', 'Business Administration Bootcamp', 'Chemistry Essentials', 'Digital Marketing Strategies', 'Linguistics Lab', 'Operations Management Mastery', 'Statistical Analysis Workshop', 'Environmental Science Explorations', 'Game Design Workshop', 'Biology Basics', 'Choreography Masterclass', 'Math Mastery', 'Astronomy Adventures', 'Urban Planning Insights', 'Aerospace Engineering Explained', 'Developmental Psychology Workshop', 'Civil Engineering Principles', 'Agricultural Innovations', 'Political Science Crash Course', 'Conflict Resolution Strategies', 'Game Theory Fundamentals', 'Pharmacology Insights', 'Geology Discovery', 'Electrical Engineering Essentials', 'Music Composition Techniques', 'Cognitive Science Explorations', 'Forensic Science Fundamentals', 'Cultural Anthropology Guide', 'Graphic Design Masterclass', 'Sociology Insights', 'Coding for Beginners', 'Art History Journey', 'Supply Chain Management Workshop', 'Literary Classics Review', 'Mechanical Engineering Workshop', 'Nanotechnology Explorations', 'World History Explained', 'Cryptocurrency Basics', 'Ethical Dilemmas Seminar', 'Biochemistry Bootcamp', 'Psychology 101', 'Economic Principles', 'Neurobiology Essentials', 'Physics Fundamentals', 'Fashion Design Studio', 'Philosophical Thinking', 'Global Geography Tour', 'English Grammar Workshop', 'Cybersecurity Essentials']
suggested_apps = ['ElectriEdu', 'CognoCraft', 'MusicMagic', 'MateriMagic', 'CodeCraft', 'CultAnthro', 'BioBuddy', 'GameGenius', 'DigitalMark', 'LitLearn', 'EthicEase', 'Histopedia', 'NeuroNest', 'PoliSciPro', 'SupplySense', 'EconEase', 'DevPsych', 'AeroEdu', 'ConflictCoach', 'NanoNexus', 'SociStudy', 'BioBlitz', 'ChemConnect', 'RenewTech', 'AstroAdvent', 'ForenTech', 'Fashionista', 'EngLang', 'GeoGuru', 'AgriApp', 'PhysicsExplorer', 'UrbanPlanner', 'GameTactics', 'ChoreoCraft', 'StatMaster', 'PhiloForum', 'OpMan', 'ArtHistoria', 'LinguaLab', 'CivilEssence', 'PsychPal', 'GeoExplorer', 'MathGenius', 'PharmaPedia', 'GraphiGenius', 'EnviroEdu', 'BizBoost', 'MechMaster', 'CyberSecPro', 'CryptoCraze']

# Create the dataset
data = {
    'Subject': np.random.choice(subjects, 1000),
    'User_Language': np.random.choice(user_languages, 1000),
    'User_Level': np.random.choice(user_levels, 1000),
    'Text_Book': np.random.choice(text_books, 1000),
    'Online_Course': np.random.choice(online_courses, 1000),
    'Suggested_App': np.random.choice(suggested_apps, 1000)
}

# Create DataFrame
data = pd.DataFrame(data)

data.head(49)
# Out:
#                      Subject User_Language    User_Level  \
# 0                     Ethics       Chinese  Intermediate
# 1                   Medicine       Spanish      Beginner
# 2               Paleontology       Spanish      Advanced
# 3      Environmental Science       Chinese      Beginner
# 4                Engineering        French      Advanced
# 5          Political Science        French  Intermediate
# 6           Renewable Energy       Spanish  Intermediate
# 7        Wilderness Survival        French  Intermediate
# 8      Aerospace Engineering       Russian      Advanced
# 9   Developmental Psychology       English  Intermediate
# 10               Engineering       English  Intermediate
# 11         Political Science       English  Intermediate
# 12          English Language        French      Beginner
# 13    Mechanical Engineering       English  Intermediate
# 14               Linguistics       Spanish  Intermediate
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder



# Separate features and target variable
X = data.drop(['Text_Book', 'Online_Course', 'Suggested_App'], axis=1)
y_textbook = data['Text_Book']
y_online_course = data['Online_Course']
y_suggested_app = data['Suggested_App']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Split the data into training and testing sets
X_train, X_test, y_textbook_train, y_textbook_test = train_test_split(X_encoded, y_textbook, test_size=0.2, random_state=42)
X_train, X_test, y_online_course_train, y_online_course_test = train_test_split(X_encoded, y_online_course, test_size=0.2, random_state=42)
X_train, X_test, y_suggested_app_train, y_suggested_app_test = train_test_split(X_encoded, y_suggested_app, test_size=0.2, random_state=42)

# Train decision tree classifiers
textbook_classifier = DecisionTreeClassifier()
textbook_classifier.fit(X_train, y_textbook_train)

online_course_classifier = DecisionTreeClassifier()
online_course_classifier.fit(X_train, y_online_course_train)

suggested_app_classifier = DecisionTreeClassifier()
suggested_app_classifier.fit(X_train, y_suggested_app_train)

# Predictions
subject = input("Enter Subject: ")
user_language = input("Enter User Language: ")
user_level = input("Enter User Level: ")

input_data = pd.DataFrame({'Subject': [subject], 'User_Language': [user_language], 'User_Level': [user_level]})
input_data_encoded = pd.get_dummies(input_data)

# Align input data with training data to ensure the same columns
input_data_encoded = input_data_encoded.reindex(columns=X_encoded.columns, fill_value=0)

textbook_prediction = textbook_classifier.predict(input_data_encoded)
online_course_prediction = online_course_classifier.predict(input_data_encoded)
suggested_app_prediction = suggested_app_classifier.predict(input_data_encoded)

print("Predicted Text_Book:", textbook_prediction[0])
print("Predicted Online_Course:", online_course_prediction[0])
print("Predicted Suggested_App:", suggested_app_prediction[0])
# Out:
# KeyboardInterrupt

# %%
# # Predictions for test set
# textbook_test_predictions = textbook_classifier.predict(X_test)
# online_course_test_predictions = online_course_classifier.predict(X_test)
# suggested_app_test_predictions = suggested_app_classifier.predict(X_test)

# # Calculate accuracy scores
# textbook_accuracy = accuracy_score(y_textbook_test, textbook_test_predictions)
# online_course_accuracy = accuracy_score(y_online_course_test, online_course_test_predictions)
# suggested_app_accuracy = accuracy_score(y_suggested_app_test, suggested_app_test_predictions)

# print("Text_Book Accuracy:", textbook_accuracy)
# print("Online_Course Accuracy:", online_course_accuracy)
# print("Suggested_App Accuracy:", suggested_app_accuracy)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'filename.csv' is the desired file name
data.to_csv('education_resources2.0.csv', index=False)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder


# Assuming 'data' is your dataset containing information about learning resources

# Separate features and target variable
X = data.drop(['Text_Book', 'Online_Course', 'Suggested_App'], axis=1)
y_textbook = data['Text_Book']
y_online_course = data['Online_Course']
y_suggested_app = data['Suggested_App']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Split the data into training and testing sets
X_train, X_test, y_textbook_train, y_textbook_test = train_test_split(X_encoded, y_textbook, test_size=0.2, random_state=42)
X_train, X_test, y_online_course_train, y_online_course_test = train_test_split(X_encoded, y_online_course, test_size=0.2, random_state=42)
X_train, X_test, y_suggested_app_train, y_suggested_app_test = train_test_split(X_encoded, y_suggested_app, test_size=0.2, random_state=42)

# Train decision tree classifiers
textbook_classifier = DecisionTreeClassifier()
textbook_classifier.fit(X_train, y_textbook_train)

online_course_classifier = DecisionTreeClassifier()
online_course_classifier.fit(X_train, y_online_course_train)

suggested_app_classifier = DecisionTreeClassifier()
suggested_app_classifier.fit(X_train, y_suggested_app_train)

# Conversation with the user
print("Hi! I'm here to assist you in finding the best learning resources for your needs.")

subject = input("What subject are you interested in learning about? (e.g., Mathematics, History, Programming) ")
user_level = input("What is your current level of expertise in this subject? (e.g., Beginner, Intermediate, Advanced) ")
user_language = input("What is your preferred language for learning? (e.g., English, Spanish, French) ")

print(f"\nGreat! Let's dive deeper. For {subject}, are you looking for traditional textbooks, online courses, or perhaps an educational app?")
preferred_type = input("Enter your preferred type (Textbooks/Online Courses/Apps) (e.g., Textbooks, Online Courses, Apps): ")

print(f"\nCould you also share any specific topics or areas within {subject} that you're particularly interested in? (e.g., Algebra, World War II, Python programming)")
specific_topic = input("Enter specific topic or interest: ")

print("\nBefore we proceed, could you tell me a bit about your learning style and preferences?")
learning_style = input("Do you prefer interactive learning experiences, in-depth theoretical explanations, or practical examples? (e.g., Interactive, Theoretical, Practical) ")

print("\nLastly, are there any specific features or functionalities you'd like the learning resource to have?")
features = input("Enter specific feature or functionality: ")

print("\nThank you for providing all those details! Based on what you've shared, I'll now recommend some tailored options for you. Please give me a moment to process your preferences.")

# Recommendation process
input_data = pd.DataFrame({'Subject': [subject], 'User_Language': [user_language], 'User_Level': [user_level]})
input_data_encoded = pd.get_dummies(input_data)

# Align input data with training data to ensure the same columns
input_data_encoded = input_data_encoded.reindex(columns=X_encoded.columns, fill_value=0)

textbook_prediction = textbook_classifier.predict(input_data_encoded)
online_course_prediction = online_course_classifier.predict(input_data_encoded)
suggested_app_prediction = suggested_app_classifier.predict(input_data_encoded)

# Print recommendations
print("\nHere are my recommendations:")
print("- Textbook:", textbook_prediction[0])
print("- Online Course:", online_course_prediction[0])
print("- Suggested App:", suggested_app_prediction[0])

print("\nWould you like more information about any of these recommendations, or is there anything else I can assist you with?")
# Out:
# Hi! I'm here to assist you in finding the best learning resources for your needs.

# %%
data=pd.read_csv("C:\\Users\\PRAJES DAS\\Downloads\\RECOMANDATION_SYSTEM.csv")
data
# Out:
#                     Subject User_Language    User_Level  \
# 0               Mathematics       English      Advanced
# 1          English Language         Hindi      Beginner
# 2                   History       English  Intermediate
# 3                   Science         Hindi      Advanced
# 4                 Geography       English      Beginner
# ..                      ...           ...           ...
# 98   Landscape Architecture       English      Beginner
# 99                Education         Hindi  Intermediate
# 100                     NaN           NaN           NaN
# 101                     NaN           NaN           NaN
# 102                     NaN           NaN           NaN
#
#                                              Text_Book  \
# 0                          "Calculus" by James Stewart
# 1    "The Norton Anthology of English Literature" e...
# 2    "A People's History of the United States" by H...
# 3                                                NCERT
# ...

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Subject          0
# User_Language    0
# User_Level       0
# Text_Book        0
# Online_Course    0
# Suggested_App    0
# dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder


# Assuming 'data' is your dataset containing information about learning resources

# Separate features and target variable
X = data.drop(['Text_Book', 'Online_Course', 'Suggested_App'], axis=1)
y_textbook = data['Text_Book']
y_online_course = data['Online_Course']
y_suggested_app = data['Suggested_App']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Split the data into training and testing sets
X_train, X_test, y_textbook_train, y_textbook_test = train_test_split(X_encoded, y_textbook, test_size=0.2, random_state=42)
X_train, X_test, y_online_course_train, y_online_course_test = train_test_split(X_encoded, y_online_course, test_size=0.2, random_state=42)
X_train, X_test, y_suggested_app_train, y_suggested_app_test = train_test_split(X_encoded, y_suggested_app, test_size=0.2, random_state=42)

# Train decision tree classifiers
textbook_classifier = DecisionTreeClassifier()
textbook_classifier.fit(X_train, y_textbook_train)

online_course_classifier = DecisionTreeClassifier()
online_course_classifier.fit(X_train, y_online_course_train)

suggested_app_classifier = DecisionTreeClassifier()
suggested_app_classifier.fit(X_train, y_suggested_app_train)

# Conversation with the user
print("Hi! I'm here to assist you in finding the best learning resources for your needs.")

subject = input("What subject are you interested in learning about? (e.g., Mathematics, History, Programming) ")
user_level = input("What is your current level of expertise in this subject? (e.g., Beginner, Intermediate, Advanced) ")
user_language = input("What is your preferred language for learning? (e.g., English, Spanish, French) ")

print(f"\nGreat! Let's dive deeper. For {subject}, are you looking for traditional textbooks, online courses, or perhaps an educational app?")
preferred_type = input("Enter your preferred type (Textbooks/Online Courses/Apps) (e.g., Textbooks, Online Courses, Apps): ")

print(f"\nCould you also share any specific topics or areas within {subject} that you're particularly interested in? (e.g., Algebra, World War II, Python programming)")
specific_topic = input("Enter specific topic or interest: ")

print("\nBefore we proceed, could you tell me a bit about your learning style and preferences?")
learning_style = input("Do you prefer interactive learning experiences, in-depth theoretical explanations, or practical examples? (e.g., Interactive, Theoretical, Practical) ")

print("\nLastly, are there any specific features or functionalities you'd like the learning resource to have?")
features = input("Enter specific feature or functionality: ")

print("\nThank you for providing all those details! Based on what you've shared, I'll now recommend some tailored options for you. Please give me a moment to process your preferences.")

# Recommendation process
input_data = pd.DataFrame({'Subject': [subject], 'User_Language': [user_language], 'User_Level': [user_level]})
input_data_encoded = pd.get_dummies(input_data)

# Align input data with training data to ensure the same columns
input_data_encoded = input_data_encoded.reindex(columns=X_encoded.columns, fill_value=0)

textbook_prediction = textbook_classifier.predict(input_data_encoded)
online_course_prediction = online_course_classifier.predict(input_data_encoded)
suggested_app_prediction = suggested_app_classifier.predict(input_data_encoded)

# Print recommendations
print("\nHere are my recommendations:")
print("- Textbook:", textbook_prediction[0])
print("- Online Course:", online_course_prediction[0])
print("- Suggested App:", suggested_app_prediction[0])

print("\nWould you like more information about any of these recommendations, or is there anything else I can assist you with?")
# Out:
# Hi! I'm here to assist you in finding the best learning resources for your needs.
# What subject are you interested in learning about? (e.g., Mathematics, History, Programming)
# What is your current level of expertise in this subject? (e.g., Beginner, Intermediate, Advanced)
# What is your preferred language for learning? (e.g., English, Spanish, French)
#
# Great! Let's dive deeper. For , are you looking for traditional textbooks, online courses, or perhaps an educational app?
# Enter your preferred type (Textbooks/Online Courses/Apps) (e.g., Textbooks, Online Courses, Apps):
#
# Could you also share any specific topics or areas within  that you're particularly interested in? (e.g., Algebra, World War II, Python programming)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 44
# ...

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy for textbook classifier
textbook_accuracy = accuracy_score(y_textbook_test, textbook_classifier.predict(X_test))

# Calculate accuracy for online course classifier
online_course_accuracy = accuracy_score(y_online_course_test, online_course_classifier.predict(X_test))

# Calculate accuracy for suggested app classifier
suggested_app_accuracy = accuracy_score(y_suggested_app_test, suggested_app_classifier.predict(X_test))

print("Accuracy for Textbook Classifier:", textbook_accuracy)
print("Accuracy for Online Course Classifier:", online_course_accuracy)
print("Accuracy for Suggested App Classifier:", suggested_app_accuracy)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder

# Assuming 'data' is your dataset containing information about learning resources

# Separate features and target variable
X = data.drop(['Text_Book', 'Online_Course', 'Suggested_App'], axis=1)
y_textbook = data['Text_Book']
y_online_course = data['Online_Course']
y_suggested_app = data['Suggested_App']

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X)

# Split the data into training and testing sets
X_train, X_test, y_textbook_train, y_textbook_test = train_test_split(X_encoded, y_textbook, test_size=0.2, random_state=42)
X_train, X_test, y_online_course_train, y_online_course_test = train_test_split(X_encoded, y_online_course, test_size=0.2, random_state=42)
X_train, X_test, y_suggested_app_train, y_suggested_app_test = train_test_split(X_encoded, y_suggested_app, test_size=0.2, random_state=42)

# Train Random Forest classifiers
textbook_classifier = RandomForestClassifier()
textbook_classifier.fit(X_train, y_textbook_train)

online_course_classifier = RandomForestClassifier()
online_course_classifier.fit(X_train, y_online_course_train)

suggested_app_classifier = RandomForestClassifier()
suggested_app_classifier.fit(X_train, y_suggested_app_train)

# Conversation with the user
print("Hi! I'm here to assist you in finding the best learning resources for your needs.")

subject = input("What subject are you interested in learning about? (e.g., Mathematics, History, Programming) ")
user_level = input("What is your current level of expertise in this subject? (e.g., Beginner, Intermediate, Advanced) ")
user_language = input("What is your preferred language for learning? (e.g., English, Spanish, French) ")

print(f"\nGreat! Let's dive deeper. For {subject}, are you looking for traditional textbooks, online courses, or perhaps an educational app?")
preferred_type = input("Enter your preferred type (Textbooks/Online Courses/Apps) (e.g., Textbooks, Online Courses, Apps): ")

print(f"\nCould you also share any specific topics or areas within {subject} that you're particularly interested in? (e.g., Algebra, World War II, Python programming)")
specific_topic = input("Enter specific topic or interest: ")

print("\nBefore we proceed, could you tell me a bit about your learning style and preferences?")
learning_style = input("Do you prefer interactive learning experiences, in-depth theoretical explanations, or practical examples? (e.g., Interactive, Theoretical, Practical) ")

print("\nLastly, are there any specific features or functionalities you'd like the learning resource to have?")
features = input("Enter specific feature or functionality: ")

print("\nThank you for providing all those details! Based on what you've shared, I'll now recommend some tailored options for you. Please give me a moment to process your preferences.")

# Recommendation process
input_data = pd.DataFrame({'Subject': [subject], 'User_Language': [user_language], 'User_Level': [user_level]})
input_data_encoded = pd.get_dummies(input_data)

# Align input data with training data to ensure the same columns
input_data_encoded = input_data_encoded.reindex(columns=X_encoded.columns, fill_value=0)

textbook_prediction = textbook_classifier.predict(input_data_encoded)
online_course_prediction = online_course_classifier.predict(input_data_encoded)
suggested_app_prediction = suggested_app_classifier.predict(input_data_encoded)

# Print recommendations     
print("\nHere are my recommendations:")
print("- Textbook:", textbook_prediction[0])
print("- Online Course:", online_course_prediction[0])
print("- Suggested App:", suggested_app_prediction[0])

print("\nWould you like more information about any of these recommendations, or is there anything else I can assist you with?")

# %%
data
# Out:
#                    Subject User_Language    User_Level  \
# 0              Mathematics       English      Advanced
# 1         English Language         Hindi      Beginner
# 2                  History       English  Intermediate
# 3                  Science         Hindi      Advanced
# 4                Geography       English      Beginner
# ..                     ...           ...           ...
# 95          Product Design         Hindi      Advanced
# 96            Architecture       English      Beginner
# 97          Urban Planning         Hindi      Advanced
# 98  Landscape Architecture       English      Beginner
# 99               Education         Hindi  Intermediate
#
#                                             Text_Book  \
# 0                         "Calculus" by James Stewart
# 1   "The Norton Anthology of English Literature" e...
# 2   "A People's History of the United States" by H...
# 3                                               NCERT
# ...

# %%
data.to_csv("education_suggestion.csv", index=False)

# %%
data
# Out:
#                    Subject User_Language    User_Level  \
# 0              Mathematics       English      Advanced
# 1         English Language         Hindi      Beginner
# 2                  History       English  Intermediate
# 3                  Science         Hindi      Advanced
# 4                Geography       English      Beginner
# ..                     ...           ...           ...
# 95          Product Design         Hindi      Advanced
# 96            Architecture       English      Beginner
# 97          Urban Planning         Hindi      Advanced
# 98  Landscape Architecture       English      Beginner
# 99               Education         Hindi  Intermediate
#
#                                             Text_Book  \
# 0                         "Calculus" by James Stewart
# 1   "The Norton Anthology of English Literature" e...
# 2   "A People's History of the United States" by H...
# 3                                               NCERT
# ...
